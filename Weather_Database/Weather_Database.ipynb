# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

from citipy import citipy

import os
os.system('say "your program has finished"')
# Out:
# 0

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

os.system('say "your program has finished"')
# Out:
# 0

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Use the print() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(coordinate[0], coordinate[1])

os.system('say "your program has finished"')
# Out:
# 0

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)

os.system('say "your program has finished"')
# Out:
# 0

# %%
# Build URL to make API call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
os.system('say "your program has finished"')
# Out:
# 0

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

os.system('say "your program has finished"')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | broome
# Processing Record 3 of Set 1 | cap malheureux
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | sept-iles
# Processing Record 6 of Set 1 | susanville
# Processing Record 7 of Set 1 | guerrero negro
# Processing Record 8 of Set 1 | jijiga
# Processing Record 9 of Set 1 | baracoa
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | okhotsk
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | klaksvik
# Processing Record 14 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | lebu
# Processing Record 22 of Set 1 | mokhotlong
# Processing Record 23 of Set 1 | codrington
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | rocha
# Processing Record 26 of Set 1 | nouadhibou
# Processing Record 27 of Set 1 | burnie
# Processing Record 28 of Set 1 | ahipara
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | emba
# Processing Record 33 of Set 1 | coquimbo
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | east london
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | gat
# Processing Record 39 of Set 1 | sitka
# Processing Record 40 of Set 1 | caconda
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | marrakesh
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | vila velha
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | severo-kurilsk
# Processing Record 47 of Set 1 | kavieng
# Processing Record 48 of Set 1 | lompoc
# Processing Record 49 of Set 1 | townsville
# Processing Record 50 of Set 1 | esperance
# Processing Record 1 of Set 2 | farafangana
# Processing Record 2 of Set 2 | ponta do sol
# Processing Record 3 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 4 of Set 2 | matane
# Processing Record 5 of Set 2 | nantucket
# Processing Record 6 of Set 2 | port lincoln
# Processing Record 7 of Set 2 | naze
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | provideniya
# Processing Record 10 of Set 2 | severnyy
# Processing Record 11 of Set 2 | matara
# Processing Record 12 of Set 2 | thomasville
# Processing Record 13 of Set 2 | qaqortoq
# Processing Record 14 of Set 2 | mandera
# Processing Record 15 of Set 2 | nanortalik
# Processing Record 16 of Set 2 | albany
# Processing Record 17 of Set 2 | kinsale
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | general pico
# Processing Record 20 of Set 2 | bilibino
# Processing Record 21 of Set 2 | vytegra
# Processing Record 22 of Set 2 | thinadhoo
# Processing Record 23 of Set 2 | sobolevo
# Processing Record 24 of Set 2 | altagracia de orituco
# Processing Record 25 of Set 2 | mahebourg
# Processing Record 26 of Set 2 | saldanha
# Processing Record 27 of Set 2 | conde
# Processing Record 28 of Set 2 | emerald
# Processing Record 29 of Set 2 | busselton
# Processing Record 30 of Set 2 | crossville
# Processing Record 31 of Set 2 | touros
# Processing Record 32 of Set 2 | bengkulu
# Processing Record 33 of Set 2 | campbell river
# Processing Record 34 of Set 2 | doka
# Processing Record 35 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 2 | yar-sale
# Processing Record 37 of Set 2 | tuktoyaktuk
# Processing Record 38 of Set 2 | adrar
# Processing Record 39 of Set 2 | gamba
# Processing Record 40 of Set 2 | isangel
# Processing Record 41 of Set 2 | novoselytsya
# Processing Record 42 of Set 2 | wanning
# Processing Record 43 of Set 2 | chernyshevskiy
# Processing Record 44 of Set 2 | pilar
# Processing Record 45 of Set 2 | cape town
# Processing Record 46 of Set 2 | chokurdakh
# Processing Record 47 of Set 2 | tournon-sur-rhone
# Processing Record 48 of Set 2 | yulara
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | georgetown
# Processing Record 1 of Set 3 | killybegs
# Processing Record 2 of Set 3 | maloshuyka
# City not found. Skipping...
# Processing Record 3 of Set 3 | marinette
# Processing Record 4 of Set 3 | faya
# Processing Record 5 of Set 3 | cape canaveral
# Processing Record 6 of Set 3 | avarua
# Processing Record 7 of Set 3 | tukrah
# Processing Record 8 of Set 3 | aklavik
# Processing Record 9 of Set 3 | noumea
# Processing Record 10 of Set 3 | lakes entrance
# Processing Record 11 of Set 3 | ahuimanu
# Processing Record 12 of Set 3 | gwadar
# Processing Record 13 of Set 3 | ambilobe
# Processing Record 14 of Set 3 | hilo
# Processing Record 15 of Set 3 | chicama
# Processing Record 16 of Set 3 | sulangan
# Processing Record 17 of Set 3 | pacific grove
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | rio grande
# Processing Record 20 of Set 3 | bayburt
# Processing Record 21 of Set 3 | punta arenas
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 3 | katherine
# Processing Record 25 of Set 3 | waspan
# Processing Record 26 of Set 3 | dingle
# Processing Record 27 of Set 3 | sao filipe
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | kilosa
# Processing Record 30 of Set 3 | hamilton
# Processing Record 31 of Set 3 | andros town
# Processing Record 32 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 3 | shahrud
# Processing Record 34 of Set 3 | bethel
# Processing Record 35 of Set 3 | mount gambier
# Processing Record 36 of Set 3 | abeche
# Processing Record 37 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 3 | portland
# Processing Record 39 of Set 3 | laguna
# Processing Record 40 of Set 3 | cidreira
# Processing Record 41 of Set 3 | iqaluit
# Processing Record 42 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 43 of Set 3 | hithadhoo
# Processing Record 44 of Set 3 | hermanus
# Processing Record 45 of Set 3 | arraial do cabo
# Processing Record 46 of Set 3 | katsuura
# Processing Record 47 of Set 3 | camacha
# Processing Record 48 of Set 3 | hasaki
# Processing Record 49 of Set 3 | kodiak
# Processing Record 50 of Set 3 | hervey bay
# Processing Record 1 of Set 4 | hay river
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | rawson
# Processing Record 4 of Set 4 | barranca
# Processing Record 5 of Set 4 | bako
# Processing Record 6 of Set 4 | lucea
# Processing Record 7 of Set 4 | monrovia
# Processing Record 8 of Set 4 | nipawin
# Processing Record 9 of Set 4 | sinnamary
# Processing Record 10 of Set 4 | cayenne
# Processing Record 11 of Set 4 | pervomayskoye
# Processing Record 12 of Set 4 | ishigaki
# Processing Record 13 of Set 4 | walajapet
# Processing Record 14 of Set 4 | torbay
# Processing Record 15 of Set 4 | mackay
# Processing Record 16 of Set 4 | liverpool
# Processing Record 17 of Set 4 | kristinehamn
# Processing Record 18 of Set 4 | lovington
# Processing Record 19 of Set 4 | azimur
# City not found. Skipping...
# Processing Record 20 of Set 4 | sovetskiy
# Processing Record 21 of Set 4 | ancud
# Processing Record 22 of Set 4 | kahului
# Processing Record 23 of Set 4 | chuy
# Processing Record 24 of Set 4 | praia da vitoria
# Processing Record 25 of Set 4 | mersing
# Processing Record 26 of Set 4 | kibaya
# Processing Record 27 of Set 4 | namatanai
# Processing Record 28 of Set 4 | lafiagi
# Processing Record 29 of Set 4 | mataura
# Processing Record 30 of Set 4 | strezhevoy
# Processing Record 31 of Set 4 | pisco
# Processing Record 32 of Set 4 | saucillo
# Processing Record 33 of Set 4 | basudebpur
# Processing Record 34 of Set 4 | opuwo
# Processing Record 35 of Set 4 | norman wells
# Processing Record 36 of Set 4 | merauke
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | barrow
# Processing Record 39 of Set 4 | vardo
# Processing Record 40 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 4 | namie
# Processing Record 42 of Set 4 | miranda de ebro
# Processing Record 43 of Set 4 | narrabri
# Processing Record 44 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 4 | tautira
# Processing Record 46 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 4 | tasiilaq
# Processing Record 48 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 4 | kavaratti
# Processing Record 50 of Set 4 | zhangye
# Processing Record 1 of Set 5 | katobu
# Processing Record 2 of Set 5 | airai
# Processing Record 3 of Set 5 | bandarbeyla
# Processing Record 4 of Set 5 | shambu
# Processing Record 5 of Set 5 | pitimbu
# Processing Record 6 of Set 5 | tiksi
# Processing Record 7 of Set 5 | talara
# Processing Record 8 of Set 5 | kharp
# Processing Record 9 of Set 5 | padang
# Processing Record 10 of Set 5 | victoria
# Processing Record 11 of Set 5 | meulaboh
# Processing Record 12 of Set 5 | huai thalaeng
# Processing Record 13 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 5 | tarakan
# Processing Record 15 of Set 5 | the pas
# Processing Record 16 of Set 5 | evensk
# Processing Record 17 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 18 of Set 5 | narsaq
# Processing Record 19 of Set 5 | varhaug
# Processing Record 20 of Set 5 | los llanos de aridane
# Processing Record 21 of Set 5 | mar del plata
# Processing Record 22 of Set 5 | axim
# Processing Record 23 of Set 5 | razole
# Processing Record 24 of Set 5 | vagur
# Processing Record 25 of Set 5 | longhua
# Processing Record 26 of Set 5 | caravelas
# Processing Record 27 of Set 5 | porto novo
# Processing Record 28 of Set 5 | tuatapere
# Processing Record 29 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 5 | cabo san lucas
# Processing Record 31 of Set 5 | derzhavinsk
# Processing Record 32 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 5 | kaitangata
# Processing Record 34 of Set 5 | zhicheng
# Processing Record 35 of Set 5 | yining
# Processing Record 36 of Set 5 | margate
# Processing Record 37 of Set 5 | kosino
# Processing Record 38 of Set 5 | half moon bay
# Processing Record 39 of Set 5 | bad neustadt
# City not found. Skipping...
# Processing Record 40 of Set 5 | pulaski
# Processing Record 41 of Set 5 | carballo
# Processing Record 42 of Set 5 | abu samrah
# Processing Record 43 of Set 5 | lazaro cardenas
# Processing Record 44 of Set 5 | tazovskiy
# Processing Record 45 of Set 5 | winslow
# Processing Record 46 of Set 5 | chupa
# Processing Record 47 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 48 of Set 5 | dikson
# Processing Record 49 of Set 5 | jahrom
# City not found. Skipping...
# Processing Record 50 of Set 5 | plettenberg bay
# Processing Record 1 of Set 6 | sinop
# Processing Record 2 of Set 6 | tsabong
# Processing Record 3 of Set 6 | yaan
# Processing Record 4 of Set 6 | wageningen
# Processing Record 5 of Set 6 | stephenville
# Processing Record 6 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 7 of Set 6 | najran
# Processing Record 8 of Set 6 | longyearbyen
# Processing Record 9 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 6 | manyana
# Processing Record 11 of Set 6 | clyde river
# Processing Record 12 of Set 6 | idrinskoye
# Processing Record 13 of Set 6 | turtas
# Processing Record 14 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 6 | taoudenni
# Processing Record 16 of Set 6 | skjervoy
# Processing Record 17 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 6 | parrita
# Processing Record 19 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 6 | rockhampton
# Processing Record 21 of Set 6 | sorland
# Processing Record 22 of Set 6 | faanui
# Processing Record 23 of Set 6 | hobyo
# Processing Record 24 of Set 6 | burica
# City not found. Skipping...
# Processing Record 25 of Set 6 | issoire
# Processing Record 26 of Set 6 | joshimath
# Processing Record 27 of Set 6 | hami
# Processing Record 28 of Set 6 | fare
# Processing Record 29 of Set 6 | moissala
# Processing Record 30 of Set 6 | peniche
# Processing Record 31 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 32 of Set 6 | halifax
# Processing Record 33 of Set 6 | topeka
# Processing Record 34 of Set 6 | moron
# Processing Record 35 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 36 of Set 6 | luanda
# Processing Record 37 of Set 6 | la libertad
# Processing Record 38 of Set 6 | coihaique
# Processing Record 39 of Set 6 | saint-prosper
# Processing Record 40 of Set 6 | fairbanks
# Processing Record 41 of Set 6 | inverell
# Processing Record 42 of Set 6 | bubaque
# Processing Record 43 of Set 6 | havre-saint-pierre
# Processing Record 44 of Set 6 | solnechnyy
# Processing Record 45 of Set 6 | oranmore
# Processing Record 46 of Set 6 | sajanan
# Processing Record 47 of Set 6 | listvyanskiy
# Processing Record 48 of Set 6 | neuquen
# Processing Record 49 of Set 6 | carbonia
# Processing Record 50 of Set 6 | tarauaca
# Processing Record 1 of Set 7 | nome
# Processing Record 2 of Set 7 | walvis bay
# Processing Record 3 of Set 7 | mayor pablo lagerenza
# Processing Record 4 of Set 7 | yelizovo
# Processing Record 5 of Set 7 | luba
# Processing Record 6 of Set 7 | port blair
# Processing Record 7 of Set 7 | college
# Processing Record 8 of Set 7 | sola
# Processing Record 9 of Set 7 | van
# Processing Record 10 of Set 7 | saint george
# Processing Record 11 of Set 7 | ulladulla
# Processing Record 12 of Set 7 | bati
# Processing Record 13 of Set 7 | bairiki
# Processing Record 14 of Set 7 | may pen
# Processing Record 15 of Set 7 | oranjestad
# Processing Record 16 of Set 7 | itarema
# Processing Record 17 of Set 7 | christchurch
# Processing Record 18 of Set 7 | leningradskiy
# Processing Record 19 of Set 7 | solginskiy
# Processing Record 20 of Set 7 | garowe
# Processing Record 21 of Set 7 | richards bay
# Processing Record 22 of Set 7 | altus
# Processing Record 23 of Set 7 | fourmies
# Processing Record 24 of Set 7 | whitehorse
# Processing Record 25 of Set 7 | bend
# Processing Record 26 of Set 7 | el faiyum
# City not found. Skipping...
# Processing Record 27 of Set 7 | bengbu
# Processing Record 28 of Set 7 | ca mau
# Processing Record 29 of Set 7 | ahmadpur
# Processing Record 30 of Set 7 | luderitz
# Processing Record 31 of Set 7 | ust-nera
# Processing Record 32 of Set 7 | necochea
# Processing Record 33 of Set 7 | taltal
# Processing Record 34 of Set 7 | ramasukha
# City not found. Skipping...
# Processing Record 35 of Set 7 | kruisfontein
# Processing Record 36 of Set 7 | neiafu
# Processing Record 37 of Set 7 | gopalpur
# Processing Record 38 of Set 7 | xuddur
# Processing Record 39 of Set 7 | saint-augustin
# Processing Record 40 of Set 7 | tarabha
# Processing Record 41 of Set 7 | srednekolymsk
# Processing Record 42 of Set 7 | kattivakkam
# Processing Record 43 of Set 7 | yinchuan
# Processing Record 44 of Set 7 | vila franca do campo
# Processing Record 45 of Set 7 | iberia
# Processing Record 46 of Set 7 | monterey
# Processing Record 47 of Set 7 | moshupa
# Processing Record 48 of Set 7 | wolmirstedt
# Processing Record 49 of Set 7 | prince rupert
# Processing Record 50 of Set 7 | camacupa
# Processing Record 1 of Set 8 | salym
# Processing Record 2 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 8 | viru
# Processing Record 4 of Set 8 | kudahuvadhoo
# Processing Record 5 of Set 8 | kalmunai
# Processing Record 6 of Set 8 | arsikere
# Processing Record 7 of Set 8 | hudson bay
# Processing Record 8 of Set 8 | addison
# Processing Record 9 of Set 8 | spirit river
# Processing Record 10 of Set 8 | capljina
# Processing Record 11 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 8 | terrace
# Processing Record 13 of Set 8 | sioux falls
# Processing Record 14 of Set 8 | onufriyivka
# Processing Record 15 of Set 8 | comodoro rivadavia
# Processing Record 16 of Set 8 | tuy hoa
# Processing Record 17 of Set 8 | husavik
# Processing Record 18 of Set 8 | xining
# Processing Record 19 of Set 8 | mogok
# Processing Record 20 of Set 8 | vao
# Processing Record 21 of Set 8 | bambous virieux
# Processing Record 22 of Set 8 | santa rosa
# Processing Record 23 of Set 8 | muisne
# Processing Record 24 of Set 8 | beloha
# Processing Record 25 of Set 8 | himora
# City not found. Skipping...
# Processing Record 26 of Set 8 | viedma
# Processing Record 27 of Set 8 | alofi
# Processing Record 28 of Set 8 | wairoa
# Processing Record 29 of Set 8 | satka
# Processing Record 30 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 31 of Set 8 | nelson bay
# Processing Record 32 of Set 8 | tessalit
# Processing Record 33 of Set 8 | prescott
# Processing Record 34 of Set 8 | kerrville
# Processing Record 35 of Set 8 | tura
# Processing Record 36 of Set 8 | mandalgovi
# Processing Record 37 of Set 8 | strzelce krajenskie
# Processing Record 38 of Set 8 | tiruvottiyur
# City not found. Skipping...
# Processing Record 39 of Set 8 | berlevag
# Processing Record 40 of Set 8 | jalu
# Processing Record 41 of Set 8 | sampit
# Processing Record 42 of Set 8 | panama city
# Processing Record 43 of Set 8 | tahoua
# Processing Record 44 of Set 8 | warwick
# Processing Record 45 of Set 8 | kisangani
# Processing Record 46 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 47 of Set 8 | marsa matruh
# Processing Record 48 of Set 8 | filadelfia
# Processing Record 49 of Set 8 | mehamn
# Processing Record 50 of Set 8 | tucumcari
# Processing Record 1 of Set 9 | hof
# Processing Record 2 of Set 9 | bondo
# Processing Record 3 of Set 9 | bereznik
# Processing Record 4 of Set 9 | novara
# Processing Record 5 of Set 9 | saiha
# Processing Record 6 of Set 9 | mantua
# Processing Record 7 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 8 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 9 | bathsheba
# Processing Record 10 of Set 9 | labuhan
# Processing Record 11 of Set 9 | mahibadhoo
# Processing Record 12 of Set 9 | atar
# Processing Record 13 of Set 9 | veraval
# Processing Record 14 of Set 9 | kurumkan
# Processing Record 15 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 9 | shu
# Processing Record 17 of Set 9 | ribeira grande
# Processing Record 18 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 19 of Set 9 | kirando
# Processing Record 20 of Set 9 | shingu
# Processing Record 21 of Set 9 | mitoc
# Processing Record 22 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 9 | muzaffarabad
# Processing Record 24 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 25 of Set 9 | port-cartier
# Processing Record 26 of Set 9 | cuenca
# Processing Record 27 of Set 9 | maua
# Processing Record 28 of Set 9 | cherskiy
# Processing Record 29 of Set 9 | ushtobe
# Processing Record 30 of Set 9 | cockburn town
# Processing Record 31 of Set 9 | nagayo
# Processing Record 32 of Set 9 | aripuana
# Processing Record 33 of Set 9 | pangnirtung
# Processing Record 34 of Set 9 | kupang
# Processing Record 35 of Set 9 | alindao
# Processing Record 36 of Set 9 | algiers
# Processing Record 37 of Set 9 | skibbereen
# Processing Record 38 of Set 9 | southampton
# Processing Record 39 of Set 9 | jepelacio
# Processing Record 40 of Set 9 | pedreira
# Processing Record 41 of Set 9 | jha jha
# Processing Record 42 of Set 9 | grindavik
# Processing Record 43 of Set 9 | chanika
# Processing Record 44 of Set 9 | komsomolskiy
# Processing Record 45 of Set 9 | astoria
# Processing Record 46 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 9 | barabinsk
# Processing Record 48 of Set 9 | talnakh
# Processing Record 49 of Set 9 | tinaquillo
# Processing Record 50 of Set 9 | boysun
# Processing Record 1 of Set 10 | trairi
# Processing Record 2 of Set 10 | bilma
# Processing Record 3 of Set 10 | kargopol
# Processing Record 4 of Set 10 | luwuk
# Processing Record 5 of Set 10 | calobre
# City not found. Skipping...
# Processing Record 6 of Set 10 | salisbury
# Processing Record 7 of Set 10 | aksu
# Processing Record 8 of Set 10 | arlit
# Processing Record 9 of Set 10 | heze
# Processing Record 10 of Set 10 | bourail
# Processing Record 11 of Set 10 | malakal
# Processing Record 12 of Set 10 | changji
# Processing Record 13 of Set 10 | westport
# Processing Record 14 of Set 10 | kangaatsiaq
# Processing Record 15 of Set 10 | alanya
# Processing Record 16 of Set 10 | ostrovnoy
# Processing Record 17 of Set 10 | dukat
# Processing Record 18 of Set 10 | biltine
# Processing Record 19 of Set 10 | zhuzhou
# Processing Record 20 of Set 10 | urucui
# Processing Record 21 of Set 10 | hattiesburg
# Processing Record 22 of Set 10 | tilichiki
# Processing Record 23 of Set 10 | sibiti
# Processing Record 24 of Set 10 | dabou
# Processing Record 25 of Set 10 | pontianak
# Processing Record 26 of Set 10 | lagoa
# Processing Record 27 of Set 10 | tambacounda
# Processing Record 28 of Set 10 | mabaruma
# Processing Record 29 of Set 10 | umm kaddadah
# Processing Record 30 of Set 10 | goderich
# Processing Record 31 of Set 10 | luang prabang
# Processing Record 32 of Set 10 | formosa do rio preto
# Processing Record 33 of Set 10 | olafsvik
# Processing Record 34 of Set 10 | kolpashevo
# Processing Record 35 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 37 of Set 10 | arak
# Processing Record 38 of Set 10 | ixtapa
# Processing Record 39 of Set 10 | mount hagen
# Processing Record 40 of Set 10 | anapolis
# Processing Record 41 of Set 10 | agadir
# Processing Record 42 of Set 10 | port alberni
# Processing Record 43 of Set 10 | ruteng
# Processing Record 44 of Set 10 | lorengau
# Processing Record 45 of Set 10 | ewa beach
# Processing Record 46 of Set 10 | antofagasta
# Processing Record 47 of Set 10 | gasa
# Processing Record 48 of Set 10 | hare bay
# Processing Record 49 of Set 10 | nassau
# Processing Record 50 of Set 10 | kirakira
# Processing Record 1 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 2 of Set 11 | fortuna
# Processing Record 3 of Set 11 | san luis
# Processing Record 4 of Set 11 | hofn
# Processing Record 5 of Set 11 | baherden
# Processing Record 6 of Set 11 | poole
# Processing Record 7 of Set 11 | mount isa
# Processing Record 8 of Set 11 | kuandian
# Processing Record 9 of Set 11 | kemijarvi
# Processing Record 10 of Set 11 | muriti
# Processing Record 11 of Set 11 | flinders
# Processing Record 12 of Set 11 | grand gaube
# Processing Record 13 of Set 11 | omsukchan
# Processing Record 14 of Set 11 | middelburg
# Processing Record 15 of Set 11 | urrao
# Processing Record 16 of Set 11 | san quintin
# Processing Record 17 of Set 11 | san rafael
# Processing Record 18 of Set 11 | salcininkai
# Processing Record 19 of Set 11 | mananjary
# Processing Record 20 of Set 11 | madona
# Processing Record 21 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 22 of Set 11 | souillac
# Processing Record 23 of Set 11 | red bluff
# Processing Record 24 of Set 11 | sulya
# Processing Record 25 of Set 11 | port hardy
# Processing Record 26 of Set 11 | registro
# Processing Record 27 of Set 11 | payson
# Processing Record 28 of Set 11 | ndele
# Processing Record 29 of Set 11 | marsaxlokk
# Processing Record 30 of Set 11 | deventer
# Processing Record 31 of Set 11 | ketchikan
# Processing Record 32 of Set 11 | belaya gora
# Processing Record 33 of Set 11 | matay
# Processing Record 34 of Set 11 | road town
# Processing Record 35 of Set 11 | eureka
# Processing Record 36 of Set 11 | borovsk
# Processing Record 37 of Set 11 | waynesville
# Processing Record 38 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 39 of Set 11 | artvin
# Processing Record 40 of Set 11 | tupik
# Processing Record 41 of Set 11 | zaysan
# Processing Record 42 of Set 11 | lasa
# Processing Record 43 of Set 11 | samarai
# Processing Record 44 of Set 11 | ramsar
# Processing Record 45 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 11 | svit
# Processing Record 47 of Set 11 | harrogate
# Processing Record 48 of Set 11 | josanicka banja
# Processing Record 49 of Set 11 | konevo
# Processing Record 50 of Set 11 | gunjur
# Processing Record 1 of Set 12 | mbini
# Processing Record 2 of Set 12 | salalah
# Processing Record 3 of Set 12 | morozovsk
# Processing Record 4 of Set 12 | bahia blanca
# Processing Record 5 of Set 12 | saskylakh
# Processing Record 6 of Set 12 | carutapera
# Processing Record 7 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 8 of Set 12 | tocopilla
# Processing Record 9 of Set 12 | guajara-mirim
# City not found. Skipping...
# Processing Record 10 of Set 12 | mogadishu
# Processing Record 11 of Set 12 | rio gallegos
# Processing Record 12 of Set 12 | sangar
# Processing Record 13 of Set 12 | nortelandia
# Processing Record 14 of Set 12 | khorixas
# Processing Record 15 of Set 12 | sadove
# Processing Record 16 of Set 12 | quang ngai
# Processing Record 17 of Set 12 | erzurum
# Processing Record 18 of Set 12 | yorba linda
# Processing Record 19 of Set 12 | bakchar
# Processing Record 20 of Set 12 | boende
# Processing Record 21 of Set 12 | payyannur
# Processing Record 22 of Set 12 | vestmannaeyjar
# Processing Record 23 of Set 12 | eskasem
# City not found. Skipping...
# Processing Record 24 of Set 12 | cumberland
# Processing Record 25 of Set 12 | bocaiuva
# Processing Record 26 of Set 12 | avanigadda
# Processing Record 27 of Set 12 | pasighat
# Processing Record 28 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 29 of Set 12 | hambantota
# Processing Record 30 of Set 12 | catuday
# Processing Record 31 of Set 12 | conakry
# Processing Record 32 of Set 12 | seoul
# Processing Record 33 of Set 12 | juba
# Processing Record 34 of Set 12 | doha
# Processing Record 35 of Set 12 | deputatskiy
# Processing Record 36 of Set 12 | gazanjyk
# Processing Record 37 of Set 12 | kieta
# Processing Record 38 of Set 12 | olavarria
# Processing Record 39 of Set 12 | raudeberg
# Processing Record 40 of Set 12 | tabou
# Processing Record 41 of Set 12 | sabang
# Processing Record 42 of Set 12 | morgan city
# Processing Record 43 of Set 12 | luau
# Processing Record 44 of Set 12 | swellendam
# Processing Record 45 of Set 12 | kapit
# Processing Record 46 of Set 12 | nuuk
# Processing Record 47 of Set 12 | astana
# Processing Record 48 of Set 12 | buala
# Processing Record 49 of Set 12 | makung
# City not found. Skipping...
# Processing Record 50 of Set 12 | kushmurun
# Processing Record 1 of Set 13 | alyangula
# Processing Record 2 of Set 13 | menongue
# Processing Record 3 of Set 13 | port hawkesbury
# Processing Record 4 of Set 13 | alugan
# Processing Record 5 of Set 13 | arman
# Processing Record 6 of Set 13 | pozo colorado
# Processing Record 7 of Set 13 | tsiroanomandidy
# Processing Record 8 of Set 13 | turukhansk
# Processing Record 9 of Set 13 | aanekoski
# Processing Record 10 of Set 13 | vanimo
# Processing Record 11 of Set 13 | puerto el triunfo
# Processing Record 12 of Set 13 | geraldton
# Processing Record 13 of Set 13 | loukhi
# Processing Record 14 of Set 13 | progreso
# Processing Record 15 of Set 13 | charters towers
# Processing Record 16 of Set 13 | steamboat springs
# Processing Record 17 of Set 13 | eenhana
# Processing Record 18 of Set 13 | luoyang
# Processing Record 19 of Set 13 | muyezerskiy
# Processing Record 20 of Set 13 | joao neiva
# Processing Record 21 of Set 13 | mangai
# Processing Record 22 of Set 13 | makakilo city
# Processing Record 23 of Set 13 | lavrentiya
# Processing Record 24 of Set 13 | warrnambool
# Processing Record 25 of Set 13 | mareeba
# Processing Record 26 of Set 13 | usiacuri
# Processing Record 27 of Set 13 | henties bay
# Processing Record 28 of Set 13 | moose factory
# Processing Record 29 of Set 13 | novo aripuana
# Processing Record 30 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 13 | novolvovsk
# City not found. Skipping...
# Processing Record 32 of Set 13 | bremerton
# Processing Record 33 of Set 13 | dzaoudzi
# Processing Record 34 of Set 13 | bahia honda
# Processing Record 35 of Set 13 | khorinsk
# Processing Record 36 of Set 13 | dali
# Processing Record 37 of Set 13 | nouakchott
# Processing Record 38 of Set 13 | nueva gerona
# Processing Record 39 of Set 13 | port moresby
# Processing Record 40 of Set 13 | upington
# Processing Record 41 of Set 13 | dalby
# Processing Record 42 of Set 13 | sivaki
# Processing Record 43 of Set 13 | ayagoz
# Processing Record 44 of Set 13 | kilindoni
# Processing Record 45 of Set 13 | barretos
# Processing Record 46 of Set 13 | kalevala
# Processing Record 47 of Set 13 | manicore
# Processing Record 48 of Set 13 | venado tuerto
# Processing Record 49 of Set 13 | bugyi
# Processing Record 50 of Set 13 | marzuq
# Processing Record 1 of Set 14 | buraydah
# Processing Record 2 of Set 14 | el tocuyo
# Processing Record 3 of Set 14 | sosnogorsk
# Processing Record 4 of Set 14 | bonavista
# Processing Record 5 of Set 14 | nioro
# Processing Record 6 of Set 14 | el balyana
# City not found. Skipping...
# Processing Record 7 of Set 14 | dunedin
# Processing Record 8 of Set 14 | nyurba
# Processing Record 9 of Set 14 | chara
# Processing Record 10 of Set 14 | zeya
# Processing Record 11 of Set 14 | puerto baquerizo moreno
# Processing Record 12 of Set 14 | salina cruz
# Processing Record 13 of Set 14 | acajutla
# Processing Record 14 of Set 14 | gweta
# Processing Record 15 of Set 14 | lagunas
# Processing Record 16 of Set 14 | cordoba
# Processing Record 17 of Set 14 | tigre
# Processing Record 18 of Set 14 | plainfield
# Processing Record 19 of Set 14 | iguatemi
# Processing Record 20 of Set 14 | northam
# Processing Record 21 of Set 14 | svetlyy
# Processing Record 22 of Set 14 | ponta delgada
# Processing Record 23 of Set 14 | iwanai
# Processing Record 24 of Set 14 | qurayyat
# Processing Record 25 of Set 14 | gunnedah
# Processing Record 26 of Set 14 | lukovetskiy
# Processing Record 27 of Set 14 | alta floresta
# Processing Record 28 of Set 14 | naron
# Processing Record 29 of Set 14 | qasigiannguit
# Processing Record 30 of Set 14 | kibala
# Processing Record 31 of Set 14 | sainte-martine
# Processing Record 32 of Set 14 | superior
# Processing Record 33 of Set 14 | iskateley
# Processing Record 34 of Set 14 | seybaplaya
# Processing Record 35 of Set 14 | sosnovo-ozerskoye
# Processing Record 36 of Set 14 | kichera
# Processing Record 37 of Set 14 | vitim
# Processing Record 38 of Set 14 | point pedro
# Processing Record 39 of Set 14 | batagay-alyta
# Processing Record 40 of Set 14 | tahta
# Processing Record 41 of Set 14 | yeppoon
# Processing Record 42 of Set 14 | weligama
# Processing Record 43 of Set 14 | grand baie
# Processing Record 44 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 45 of Set 14 | tekeli
# Processing Record 46 of Set 14 | turayf
# Processing Record 47 of Set 14 | ilinskiy
# Processing Record 48 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 49 of Set 14 | flin flon
# Processing Record 50 of Set 14 | micheweni
# Processing Record 1 of Set 15 | palmer
# Processing Record 2 of Set 15 | port hedland
# Processing Record 3 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 4 of Set 15 | kindu
# Processing Record 5 of Set 15 | shrewsbury
# Processing Record 6 of Set 15 | tucuman
# Processing Record 7 of Set 15 | muroto
# Processing Record 8 of Set 15 | fernley
# Processing Record 9 of Set 15 | male
# Processing Record 10 of Set 15 | pangoa
# Processing Record 11 of Set 15 | chapais
# Processing Record 12 of Set 15 | onverwacht
# Processing Record 13 of Set 15 | panna
# Processing Record 14 of Set 15 | kaele
# Processing Record 15 of Set 15 | ballina
# Processing Record 16 of Set 15 | strasshof
# City not found. Skipping...
# Processing Record 17 of Set 15 | skowhegan
# Processing Record 18 of Set 15 | isselburg
# Processing Record 19 of Set 15 | balkanabat
# Processing Record 20 of Set 15 | avera
# Processing Record 21 of Set 15 | kamenka
# Processing Record 22 of Set 15 | linaon
# Processing Record 23 of Set 15 | ossora
# Processing Record 24 of Set 15 | neftcala
# Processing Record 25 of Set 15 | araguatins
# City not found. Skipping...
# Processing Record 26 of Set 15 | ayios nikolaos
# Processing Record 27 of Set 15 | nambiyur
# Processing Record 28 of Set 15 | bokovskaya
# Processing Record 29 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 30 of Set 15 | banda aceh
# Processing Record 31 of Set 15 | buckeye
# Processing Record 32 of Set 15 | concarneau
# Processing Record 33 of Set 15 | trelew
# Processing Record 34 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 15 | muros
# Processing Record 36 of Set 15 | karachi
# Processing Record 37 of Set 15 | satkhira
# Processing Record 38 of Set 15 | sao luiz gonzaga
# Processing Record 39 of Set 15 | sioux lookout
# Processing Record 40 of Set 15 | gualaquiza
# Processing Record 41 of Set 15 | kloulklubed
# Processing Record 42 of Set 15 | gavrilovka vtoraya
# Processing Record 43 of Set 15 | booue
# Processing Record 44 of Set 15 | port augusta
# Processing Record 45 of Set 15 | srandakan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 0

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Pevek      RU  69.7008  170.3133     32.43        86          99
# 1          Broome      US  42.2506  -75.8330     65.61        86           0
# 2  Cap Malheureux      MU -19.9842   57.6142     72.46        71          37
# 3     Port Alfred      ZA -33.5906   26.8910     77.18        32           2
# 4       Sept-Iles      CA  50.2001  -66.3821     57.06        90          96
# 5      Susanville      US  40.4163 -120.6530     61.92        46           0
# 6  Guerrero Negro      MX  27.9769 -114.0611     66.40        87           0
# 7          Jijiga      ET   9.3500   42.8000     65.43        71          85
# 8         Baracoa      CU  20.3467  -74.4958     78.66        89           3
# 9       Upernavik      GL  72.7868  -56.1549     41.86        87          98
#
#    Wind Speed Current Description
# 0       28.32     overcast clouds
# 1        1.01           clear sky
# 2        8.99    scattered clouds
# 3        7.00           clear sky
# 4        5.12     overcast clouds
# 5        3.00           clear sky
# 6        7.07           clear sky
# 7       22.10     overcast clouds
# 8        1.63           clear sky
# 9        3.27     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
